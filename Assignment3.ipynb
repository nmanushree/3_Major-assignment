# %%
import pandas as pd
import networkx as nx
import json
import matplotlib.pyplot as plt
import seaborn as sns
from networkx.readwrite import json_graph
from IPython.display import display

# %%
data = pd.read_csv("/content/drive/MyDrive/Assignment3/data/Data.csv")
remove = ['Abstract', 'Conference name', 'Conference date', 'Abbreviated Source Title']
data.drop(columns=remove, inplace=True)
data = data[~pd.isnull(data['Authors'])].copy()
data = data[~pd.isnull(data['Authors with affiliations'])].copy()
data = data[~pd.isnull(data['Year'])].copy()
data = data[~pd.isnull(data['Publisher'])].copy()
data['Cited by'].fillna(0.0, inplace=True)
data.head(2)
# Out:
#                                                Title  Year  \
# 0  Virtual reality applications for the built env...  2020
# 1  Self-tracking while doing sport: Comfort, moti...  2020
#
#                   EID       Publisher  \
# 0  2-s2.0-85086464158   Elsevier B.V.
# 1  2-s2.0-85082875828  Academic Press
#
#                                        Authors  \
# 0  Zhang Y., Liu H., Kang S.-C., Al-Hussein M.
# 1                         Rapp A., Tirabeni L.
#
#                                       Author(s) ID  \
# 0  57202536919;53984550800;57215426514;6603541102;
# 1                         23398572100;57191836654;
#
#                            Authors with affiliations  \
# 0  Zhang, Y., Department of Civil and Environment...
# 1  Rapp, A., Computer Science Department, Univers...
#
#                                       Source title  Cited by
# 0                       Automation in Construction       0.0
# 1  International Journal of Human Computer Studies       0.0

# %%
def get_first_author_affilation(x):
  try:
    countries = []
    affiliations = x.split(";")
    for aff in affiliations:
      countries.append(aff.split(",")[-1].strip())
    my_string = ','.join(map(str, countries))
    return my_string
  except Exception as ex:
    print(x)

data['Author_Countries']=data['Authors with affiliations'].apply(get_first_author_affilation)
data.head()
# Out:
#                                                Title  Year  \
# 0  Virtual reality applications for the built env...  2020
# 1  Self-tracking while doing sport: Comfort, moti...  2020
# 2  Bridge damage: Detection, IFC-based semantic e...  2020
# 3  VR system for spatio-temporal visualization of...  2019
# 4  DiseaSE: A biomedical text analytics system fo...  2019
#
#                   EID            Publisher  \
# 0  2-s2.0-85086464158        Elsevier B.V.
# 1  2-s2.0-85082875828       Academic Press
# 2  2-s2.0-85078194587        Elsevier B.V.
# 3  2-s2.0-85075706132             Springer
# 4  2-s2.0-85074886243  Academic Press Inc.
#
#                                              Authors  \
# 0        Zhang Y., Liu H., Kang S.-C., Al-Hussein M.
# 1                               Rapp A., Tirabeni L.
# 2  Isailović D., Stojanovic V., Trapp M., Richter...
# 3  Okada K., Yoshida M., Itoh T., Czauderna T., S...
# 4               Abulaish M., Parwez M.A., Jahiruddin
#
#                                         Author(s) ID  \
# 0    57202536919;53984550800;57215426514;6603541102;
# 1                           23398572100;57191836654;
# 2  57205293410;56421700900;24831175200;3619515940...
# 3  57201502480;57171240600;35373203100;2592569550...
# 4                6505934038;57202719622;35590173900;
#
#                            Authors with affiliations  \
# 0  Zhang, Y., Department of Civil and Environment...
# 1  Rapp, A., Computer Science Department, Univers...
# 2  Isailović, D., Department for Construction Pro...
# 3  Okada, K., Ochanomizu University, Tokyo, Japan...
# 4  Abulaish, M., Department of Computer Science, ...
#
#                                       Source title  Cited by  \
# 0                       Automation in Construction       0.0
# 1  International Journal of Human Computer Studies       0.0
# 2                       Automation in Construction       0.0
# 3                Multimedia Tools and Applications       0.0
# 4                Journal of Biomedical Informatics       0.0
#
#                                 Author_Countries
# 0             Canada,United States,Canada,Canada
# 1                                    Italy,Italy
# 2  Serbia,Germany,Germany,Germany,Serbia,Germany
# 3          Japan,Japan,Japan,Australia,Australia
# 4                              India,India,India

# %%
set_countries = set()
for index,row in data.iterrows():
    for i in row['Author_Countries'].split(","):
        set_countries.add(i)
set_countries
# Out:
# {'Australia',
#  'Austria',
#  'Belgium',
#  'Brazil',
#  'Bulgaria',
#  'Canada',
#  'Chile',
#  'China',
#  'Colombia',
#  'Croatia',
#  'Czech Republic',
#  'Denmark',
#  'Ecuador',
#  'Egypt',
#  'Finland',
#  'France',
#  'Gabon',
#  'Germany',
#  'Greece',
#  'Hong Kong',
#  'Hungary',
#  'India',
#  'Indonesia',
#  'Iran',
#  'Iraq',
#  'Ireland',
#  'Italy',
#  'Japan',
#  'Kazakhstan',
#  'Lebanon',
#  'Netherlands',
#  'Norway',
#  'Pakistan',
#  'Philippines',
#  'Poland',
#  'Polytechnic Univ',
#  'Portugal',
#  'Qatar',
#  'Romania',
#  'Russian Federation',
#  'Saudi Arabia',
#  'Serbia',
#  'Singapore',
#  'Slovakia',
#  'South Korea',
#  'Spain',
#  'Sweden',
#  'Switzerland',
#  'Taiwan',
#  'Thailand',
#  'Trinidad and Tobago',
#  'Tunisia',
#  'Turkey',
#  'United Kingdom',
#  'United States',
#  'Univ of Massachusetts at Lowell',
#  'Visible Decisions Inc'}

# %%
import networkx as nx

# Create a graph
G = nx.Graph()

# Dictionary to store nodes with author_id as the key
nodes_dict = {}

# Iterate through the DataFrame
for index, row in data.iterrows():
    author_ids = row['Author(s) ID'].split(';')
    countries = row['Author_Countries'].split(',')
    names = row['Authors'].split(',')

    for i, author_id in enumerate(author_ids):
        if author_id not in nodes_dict:
            # Check if there are corresponding values for 'names' and 'countries'
            name = names[i].strip() if i < len(names) else ''
            country = countries[i] if i < len(countries) else ''

            nodes_dict[author_id] = {
                "Name": name,
                "country": country,
                "num_publications": 0,
                "num_citations": 0,
                "degree": 0,
                "id": author_id
            }

        nodes_dict[author_id]["num_publications"] += 1
        nodes_dict[author_id]["num_citations"] += row['Cited by']
        nodes_dict[author_id]["degree"] += len(author_ids) - 1

# Convert the dictionary values to a list
nodes = list(nodes_dict.values())

# Add nodes to the graph
for node in nodes:
    G.add_node(node["id"], **node)

# Print the graph nodes with data
print(G.nodes(data=True))
# Out:
# [('57202536919', {'Name': 'Zhang Y.', 'country': 'Canada', 'num_publications': 1, 'num_citations': 0.0, 'degree': 4, 'id': '57202536919'}), ('53984550800', {'Name': 'Liu H.', 'country': 'United States', 'num_publications': 2, 'num_citations': 19.0, 'degree': 8, 'id': '53984550800'}), ('57215426514', {'Name': 'Kang S.-C.', 'country': 'Canada', 'num_publications': 1, 'num_citations': 0.0, 'degree': 4, 'id': '57215426514'}), ('6603541102', {'Name': 'Al-Hussein M.', 'country': 'Canada', 'num_publications': 2, 'num_citations': 19.0, 'degree': 8, 'id': '6603541102'}), ('', {'Name': '', 'country': '', 'num_publications': 341, 'num_citations': 4673.0, 'degree': 1133, 'id': ''}), ('23398572100', {'Name': 'Rapp A.', 'country': 'Italy', 'num_publications': 2, 'num_citations': 50.0, 'degree': 4, 'id': '23398572100'}), ('57191836654', {'Name': 'Tirabeni L.', 'country': 'Italy', 'num_publications': 1, 'num_citations': 0.0, 'degree': 2, 'id': '57191836654'}), ('57205293410', {'Name': 'Isailović D.', 'country': 'Serbia', 'num_publications': 1, 'num_citations': 0.0, 'degree': 6, 'id': '57205293410'}), ('56421700900', {'Name': 'Stojanovic V.', 'country': 'Germany', 'num_publications': 1, 'num_citations': 0.0, 'degree': 6, 'id': '56421700900'}), ('24831175200', {'Name': 'Trapp M.', 'country': 'Germany', 'num_publications': 1, 'num_citations': 0.0, 'degree': 6, 'id': '24831175200'}), ('36195159400', {'Name': 'Richter R.', 'country': 'Germany', 'num_publications': 1, 'num_citations': 0.0, 'degree': 6, 'id': '36195159400'}), ('6507346536', {'Name': 'Hajdin R.', 'country': 'Serbia', 'num_publications': 1, 'num_citations': 0.0, 'degree': 6, 'id': '6507346536'}), ('6602981892', {'Name': 'Döllner J.', 'country': 'Germany', 'num_publications': 1, 'num_citations': 0.0, 'degree': 6, 'id': '6602981892'}), ('57201502480', {'Name': 'Okada K.', 'country': 'Japan', 'num_publications': 1, 'num_citations': 0.0, 'degree': 5, 'id': '57201502480'}), ('57171240600', {'Name': 'Yoshida M.', 'country': 'Japan', 'num_publications': 1, 'num_citations': 0.0, 'degree': 5, 'id': '57171240600'}), ('35373203100', {'Name': 'Itoh T.', 'country': 'Japan', 'num_publications': 1, 'num_citations': 0.0, 'degree': 5, 'id': '35373203100'}), ('25925695500', {'Name': 'Czauderna T.', 'country': 'Australia', 'num_publications': 1, 'num_citations': 0.0, 'degree': 5, 'id': '25925695500'}), ('57200282319', {'Name': 'Stephens K.', 'country': 'Australia', 'num_publications': 1, 'num_citations': 0.0, 'degree': 5, 'id': '57200282319'}), ('6505934038', {'Name': 'Abulaish M.', 'country': 'India', 'num_publications': 1, 'num_citations': 0.0, 'degree': 3, 'id': '6505934038'}), ('57202719622', {'Name': 'Parwez M.A.', 'country': 'India', 'num_publications': 1, 'num_citations': 0.0, 'degree': 3, 'id': '57202719622'}), ('35590173900', {'Name': 'Jahiruddin', 'country': 'India', 'num_publications': 1, 'num_citations': 0.0, 'degree': 3, 'id': '35590173900'}), ('14628356000', {'Name': 'El Ammari K.', 'country': 'Canada', 'num_publications': 1, 'num_citations': 4.0, 'degree': 2, 'id': '14628356000'}), ('7006162997', {'Name': 'Hammad A.', 'country': 'Canada', 'num_publications': 2, 'num_citations': 95.0, 'degree': 5, 'id': '7006162997'}), ('57204951915', {'Name': 'Yang S.Y.', 'country': 'China', 'num_publications': 2, 'num_citations': 1.0, 'degree': 12, 'id': '57204951915'}), ('36656019700', {'Name': 'Jiang R.G.', 'country': 'China', 'num_publications': 3, 'num_citations': 1.0, 'degree': 19, 'id': '36656019700'}), ('8399981200', {'Name': 'Xie J.C.', 'country': 'China', 'num_publications': 3, 'num_citations': 1.0, 'degree': 19, 'id': '8399981200'}), ('57196119394', {'Name': 'Yu X.', 'country': 'China', 'num_publications': 2, 'num_citations': 1.0, 'degree': 13, 'id': '57196119394'}), ('57204952424', {'Name': 'Liang J.C.', 'country': 'China', 'num_publications': 3, 'num_citations': 1.0, 'degree': 19, 'id': '57204952424'}), ('57213421778', {'Name': 'Lian Y.N.', 'country': 'China', 'num_publications': 1, 'num_cita ...

# %%
# Create edges
edges = []
for _, row in data.iterrows():
    author_ids = row['Author(s) ID'].split(';')
    if len(author_ids) > 1:
        for i, author1 in enumerate(author_ids):
            for j in range(i + 1, len(author_ids)):
                edges.append((author1, author_ids[j]))

# Add edges to the graph
G.add_edges_from(edges)

# Print the graph edges with data
print(G.edges(data=True))
# Out:
# [('57202536919', '53984550800', {}), ('57202536919', '57215426514', {}), ('57202536919', '6603541102', {}), ('57202536919', '', {}), ('53984550800', '57215426514', {}), ('53984550800', '6603541102', {}), ('53984550800', '', {}), ('53984550800', '57204697057', {}), ('53984550800', '55642611800', {}), ('57215426514', '6603541102', {}), ('57215426514', '', {}), ('6603541102', '', {}), ('6603541102', '57204697057', {}), ('6603541102', '55642611800', {}), ('', '23398572100', {}), ('', '57191836654', {}), ('', '57205293410', {}), ('', '56421700900', {}), ('', '24831175200', {}), ('', '36195159400', {}), ('', '6507346536', {}), ('', '6602981892', {}), ('', '57201502480', {}), ('', '57171240600', {}), ('', '35373203100', {}), ('', '25925695500', {}), ('', '57200282319', {}), ('', '6505934038', {}), ('', '57202719622', {}), ('', '35590173900', {}), ('', '14628356000', {}), ('', '7006162997', {}), ('', '57204951915', {}), ('', '36656019700', {}), ('', '8399981200', {}), ('', '57196119394', {}), ('', '57204952424', {}), ('', '57213421778', {}), ('', '57210571032', {}), ('', '36995837100', {}), ('', '6603639150', {}), ('', '57208132039', {}), ('', '57193809880', {}), ('', '57208123780', {}), ('', '7402264252', {}), ('', '7401951879', {}), ('', '57202410843', {}), ('', '57189029589', {}), ('', '57202995868', {}), ('', '56142103500', {}), ('', '57204058927', {}), ('', '57201030837', {}), ('', '14031725600', {}), ('', '35291520900', {}), ('', '57193082748', {}), ('', '57210803755', {}), ('', '56434720200', {}), ('', '57207859284', {}), ('', '25929119800', {}), ('', '55809641900', {}), ('', '57140618200', {}), ('', '55537800900', {}), ('', '57208164221', {}), ('', '57208160887', {}), ('', '57193387530', {}), ('', '56520099600', {}), ('', '39661236700', {}), ('', '6602415651', {}), ('', '39661131900', {}), ('', '55205882400', {}), ('', '7801408662', {}), ('', '36628922400', {}), ('', '57215455402', {}), ('', '56651946700', {}), ('', '55460966100', {}), ('', '55616335800', {}), ('', '57215430538', {}), ('', '7102833923', {}), ('', '57204697057', {}), ('', '55642611800', {}), ('', '57211746412', {}), ('', '57207965699', {}), ('', '7004102300', {}), ('', '56431008400', {}), ('', '57196246369', {}), ('', '12753630700', {}), ('', '8883542500', {}), ('', '57215199843', {}), ('', '16240506100', {}), ('', '57215301099', {}), ('', '8970885700', {}), ('', '57215471286', {}), ('', '26967815900', {}), ('', '57196245087', {}), ('', '57196235017', {}), ('', '8901086000', {}), ('', '57196243666', {}), ('', '57194096523', {}), ('', '6506936856', {}), ('', '57205150427', {}), ('', '57196485592', {}), ('', '26432010400', {}), ('', '57205148331', {}), ('', '56951397100', {}), ('', '57194205876', {}), ('', '57211289116', {}), ('', '57211289059', {}), ('', '57216903968', {}), ('', '6602329136', {}), ('', '6507551266', {}), ('', '43060962600', {}), ('', '55243383400', {}), ('', '8890861400', {}), ('', '57211297330', {}), ('', '41561201100', {}), ('', '56487883000', {}), ('', '57211298374', {}), ('', '57207861153', {}), ('', '57211292289', {}), ('', '57205463012', {}), ('', '57211289040', {}), ('', '57213458125', {}), ('', '22034358400', {}), ('', '35312623600', {}), ('', '24824284200', {}), ('', '7004880755', {}), ('', '7003391364', {}), ('', '21743210600', {}), ('', '57197711780', {}), ('', '57190977894', {}), ('', '57188533542', {}), ('', '55387242800', {}), ('', '16549490300', {}), ('', '15019389800', {}), ('', '55876291800', {}), ('', '15128929600', {}), ('', '56291686300', {}), ('', '55246542700', {}), ('', '57196071898', {}), ('', '57188805324', {}), ('', '55995663400', {}), ('', '56044356400', {}), ('', '55813011500', {}), ('', '57201746983', {}), ('', '7409753328', {}), ('', '57191849627', {}), ('', '57204638514', {}), ('', '22835623800', {}), ('', '35180344300', {}), ('', '57189248122', {}), ('', '6506654143', {}), ('', '24483494000', {}), ('', '56117176800', {}), ('', '56409084200', {}), ('', '36664584200', {}), ('', '7401934994', {}), ('', '55718307400', ...

# %%
pos = nx.spring_layout(G)
nx.draw(G,pos=pos, node_size=40,alpha=.2)

# %%
with open("/content/drive/MyDrive/Assignment3/data/network_data.json",'w') as f:
  json.dump(json_graph.node_link_data(G),f)
